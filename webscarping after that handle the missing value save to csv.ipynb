# %%
import pandas as pd
import numpy as np
data=pd.read_csv("C:\\Users\DELL\Covid_data.csv")
data
# Out:
#         Country,Other   TotalCases NewCases TotalDeaths NewDeaths  \
# 0               World  189,785,698   79,687   4,084,260     1,518
# 1                 USA   34,887,155      NaN     624,214       NaN
# 2               India   31,026,829      954     412,563       NaN
# 3              Brazil   19,262,518      NaN     539,050       NaN
# 4              Russia    5,907,999   25,704     146,868       799
# ..                ...          ...      ...         ...       ...
# 218  Marshall Islands            4      NaN         NaN       NaN
# 219             Samoa            3      NaN         NaN       NaN
# 220      Saint Helena            2      NaN         NaN       NaN
# 221        Micronesia            1      NaN         NaN       NaN
# 222             China       92,183       36       4,636       NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical TotCases/1M pop  \
# 0      173,192,828       61,430  12,508,610           79,393          24,348
# ...

# %%
d1=data.fillna(0)
d1
# Out:
#         Country,Other   TotalCases NewCases TotalDeaths NewDeaths  \
# 0               World  189,785,698   79,687   4,084,260     1,518
# 1                 USA   34,887,155        0     624,214         0
# 2               India   31,026,829      954     412,563         0
# 3              Brazil   19,262,518        0     539,050         0
# 4              Russia    5,907,999   25,704     146,868       799
# ..                ...          ...      ...         ...       ...
# 218  Marshall Islands            4        0           0         0
# 219             Samoa            3        0           0         0
# 220      Saint Helena            2        0           0         0
# 221        Micronesia            1        0           0         0
# 222             China       92,183       36       4,636         0
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical TotCases/1M pop  \
# 0      173,192,828       61,430  12,508,610           79,393          24,348
# ...

# %%
d1.to_csv('p2.csv')
